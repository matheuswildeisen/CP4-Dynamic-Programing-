# %% [markdown]
# # Questão 2 — Consumo de energia
# Comparação entre força bruta e dividir e conquistar.

# %%
from pathlib import Path
import sys, csv
root = Path.cwd()
if not (root / 'src').exists():
    root = root.parent
sys.path.insert(0, str(root))
from src.brute_force import brute_force_max_interval
from src.divide_conquer import max_interval
with open(root / 'data' / 'problema2.csv', encoding='utf8') as file:
    rows = list(csv.DictReader(file))
values = [float(row['criticidade']) for row in rows[:500]]
print('Força bruta:', brute_force_max_interval(values)[0])
print('D&C:', max_interval(values))
